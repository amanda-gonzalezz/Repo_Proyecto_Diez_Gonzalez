# %%
import pandas as pd
df = pd.read_csv("datos_electorales_database_limpia.csv")
df.head()
# Out:
#                                  id_candidato  \
# 0      FERNANDO_ALEX_FERNANDEZ_BARRAZA__ARICA
# 1         SERGIO_LEANDRO_MORALES_IMANA__ARICA
# 2           ANTONIO_LUCIO_MAITA_FLORES__ARICA
# 3  DAVID_JORGE_ANTONIO_PADILLA_RAMIREZ__ARICA
# 4            ALEXANDRA_CASTILLO_BACIAN__ARICA
#
#                       nombre_candidato sexo                        región  \
# 0      FERNANDO ALEX FERNANDEZ BARRAZA    H  REGIÓN DE ARICA Y PARINACOTA
# 1         SERGIO LEANDRO MORALES IMAÑA    H  REGIÓN DE ARICA Y PARINACOTA
# 2           ANTONIO LUCIO MAITA FLORES    H  REGIÓN DE ARICA Y PARINACOTA
# 3  DAVID JORGE ANTONIO PADILLA RAMIREZ    H  REGIÓN DE ARICA Y PARINACOTA
# 4            ALEXANDRA CASTILLO BACIAN    M  REGIÓN DE ARICA Y PARINACOTA
#
#   circunscripción letra_lista                         pacto subpacto  \
# 0           ARICA           B  IZQUIERDA ECOLOGISTA POPULAR      NaN
# 1           ARICA           B  IZQUIERDA ECOLOGISTA POPULAR      NaN
# ...
